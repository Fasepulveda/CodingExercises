# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("pecan.txt", delimiter="\t")

# %%
data = df.drop(columns=["Row ID"])

# %%
X = data.drop(columns=["Pecan Yield"])
Y = data[("Pecan Yield")].values

# %%
plt.scatter(df["Fertilizer per acre"], df["Pecan Yield"])

# %%
import torch 
import torch.nn as nn
import torch.optim as optim
from sklearn.model_section
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_40676/4209047847.py in <module>
# ----> 1 import torch
#       2 import totch.nn as nn
#       3 import torch.optim as optim
#
# ModuleNotFoundError: No module named 'torch'
